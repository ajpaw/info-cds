# %% [markdown]
# # Notebook for cleaning & processing the dataset before sampling

# %%
import pandas as pd
import sys
import os
import multiprocessing
import montreal_forced_aligner
import numpy as np
import ast
import engCDSutils as util
import importlib
importlib.reload(util)

# %%
# Replace the below links according to the file structure on your local computer

directory_with_corpora = 'infoTheoryProj/allTextInputs'
directory_of_mfa =  'MFA/pretrained_models/dictionary'
directory_of_csv = 'infoTheoryProj/dataScrape'
directory_of_output = 'infoTheoryProj/dictAlignment'
directory_of_g2p = 'MFA/pretrained_models/g2p'

# %% [markdown]
# ### Part 1 of the data cleaning pipeline : Basic pre-processing and first pass of g2p (dictionary based)

# %%
def runNotebookp1(corpus_name, dict_name):
    df_path = os.path.join(directory_of_csv,corpus_name+".csv")
    og_df = pd.read_csv(df_path)
    cds_df = og_df[(og_df['speaker_role'] !='Target_Child') & (og_df['speaker_role'] !='Investigator')]
    cds_utt_list = list(cds_df['gloss'])
    print("Total number of CDS utterances in corpus (includes null values):", len(cds_utt_list))
    cds_utt_list = [x for x in cds_utt_list if x is not np.nan]
    print("Total number of non-null CDS utterances in corpus:", len(cds_utt_list))
    
    list_of_names = []
    with open('dictAlignment/'+ corpus_name+ '_names.txt', 'r') as file:
        name_list_v1 = [line.strip() for line in file]
        for i in name_list_v1:
            newi = i.strip(".,!?;:\"()[]{}").lower()
            if "'s" in newi:
                list_of_names.append(newi[:-2])
            newi=newi.replace("'", "")
            list_of_names.append(newi)
            if len(newi)>2 and newi[-1]=="s":
                list_of_names.append(newi[:-1])
    
    cleaned_words, length ,thrown_out = util.preProcess(cds_utt_list,list_of_names)
    
    link_to_dict = os.path.join(directory_of_mfa, dict_name)
    transcribed_text, length_of_cleaned, unrecog_ctr = util.createTranscription(cleaned_words,link_to_dict)
    list_of_unrecognized_words=[]
    for word,transcription in transcribed_text.items():
        if transcription =='':
                list_of_unrecognized_words.append(word)

    print("Total number of word tokens which could not be recognized in dictionary-based g2p:", unrecog_ctr)            
    print("Total number of UNIQUE word types which could not be recognized in dictionary-based g2p:", len(list_of_unrecognized_words))  
    print("Percentage of total word tokens it could not transcribe: ", 100*unrecog_ctr/length_of_cleaned, "%")
    
    
    ## Making a text file of unrecognizable words which will go in next round of g2p (phonology based)
    unrecognized_df = pd.DataFrame(list_of_unrecognized_words)
    csvpath = os.path.join(directory_of_output, corpus_name+'_unrecog_errors.txt')
    unrecognized_df.to_csv(csvpath,index=False,header=False)
    
    cds_df_nonnull =cds_df[~cds_df['gloss'].isna()]  
    preprocessed_df = util.preProcessCSV(cds_df_nonnull,list_of_Newman_names)
    
    return transcribed_text, preprocessed_df

# %% [markdown]
# ### Part 2 of the data cleaning pipeline : Treating some words manually and then second pass through g2p (phonology based)

# %%
def runNotebookp2(corpus_name, dict_name):
    name_of_mfa = dict_name[:-5]
    path_to_text = os.path.join(directory_of_output, corpus_name+'_unrecog_errors_treated.txt')
    output_path = os.path.join(directory_of_output, corpus_name+'_secondpass_result.txt')
    util.create_and_submit_job(path_to_text, name_of_mfa,output_path)
    return output_path

# %% [markdown]
# ### Part 3 of the data cleaning pipeline : Preparing the final gloss in a clean csv

# %%
def runNotebookp3(corpus_name, dict_name, output_path,transcribed_text,preprocessed_df):   
    dictionary_from_second_pass = util.giveDictionary(output_path)
    
    transcribed_text.update(dictionary_from_second_pass)
    
    result_dict, result_df, stillerror = util.prepareGlossedCSV(preprocessed_df, corpus_name,transcribed_text,directory_of_output)
    
    phonemic_cleaned = []
    for x in result_df['phonemic_gloss']:
        x_clean = []

        ctr = 0
        phonemecount = 0
        for y in x: 
            phonemecount+=len(y)
            if y!='':
                ctr +=1
                x_clean.append(y) 
        phonemic_cleaned.append(x_clean)

    result_df['phonemic_cleaned']= phonemic_cleaned  
    ipa_output_path = os.path.join(directory_of_output, corpus_name+'_ipa_result.csv')
    result_df.to_csv(ipa_output_path,index=False)
    return result_df

# %% [markdown]
# Trying the pipeline on the first corpus, NewmanRatner

# %%
transcribed_text, preprocessed_df = runNotebookp1('NewmanRatner','english_us_mfa.dict')

# %%
path = runNotebookp2('NewmanRatner','english_us_mfa.dict')
# Out:
# Your job 4795573 ("job_script_item_name.sh") has been submitted

# %%
final_df = runNotebookp3('NewmanRatner','english_us_mfa.dict', path ,transcribed_text,preprocessed_df)
# Out:
# 146158

# %%
final_df
# Out:
#              id                                        gloss  \
# 3       2647047                                 oh yeah sure
# 5       2647067                                          mhm
# 7       2647084                             alright okay xxx
# 8       2647089                              what looks good
# 10      2647108                              what looks good
# ...         ...                                          ...
# 208557  2861987                                         yeah
# 208594  2862545                           can you say pencil
# 208603  2862655                 that's when he usually signs
# 208604  2862668  so I'll be surprised if he actually does it
# 208626  2863000                                      oh yeah
#
#                                        stem  actual_phonology  \
# 3                              oh yeah sure               NaN
# 5                                       mhm               NaN
# 7                              alright okay               NaN
# 8                            what look good               NaN
# 10                           what look good               NaN
# ...                                     ...               ...
# 208557                                 yeah               NaN
# 208594                   can you say pencil               NaN
# 208603              that when he usual sign               NaN
# 208604  so I be surprise if he actual do it               NaN
# 208626                              oh yeah               NaN
#
#         model_phonology                 type language  num_morphemes  \
# 3                   NaN          declarative      eng              3
# 5                   NaN          declarative      eng              1
# 7                   NaN          declarative      eng              2
# 8                   NaN             question      eng              4
# 10                  NaN             question      eng              4
# ...                 ...                  ...      ...            ...
# 208557              NaN  imperative_emphatic      eng              1
# 208594              NaN             question      eng              4
# 208603              NaN          declarative      eng              9
# 208604              NaN          declarative      eng             14
# 208626              NaN          declarative      eng              2
#
#         num_tokens  utterance_order  ... media_unit collection_name  \
# 3                3                4  ...        NaN          Eng-NA
# 5                1                6  ...          s          Eng-NA
# 7                3                8  ...          s          Eng-NA
# 8                3                9  ...        NaN          Eng-NA
# 10               3               11  ...          s          Eng-NA
# ...            ...              ...  ...        ...             ...
# 208557           1              596  ...        NaN          Eng-NA
# 208594           4              633  ...          s          Eng-NA
# 208603           5              642  ...          s          Eng-NA
# 208604           9              643  ...          s          Eng-NA
# 208626           2              665  ...          s          Eng-NA
#
#        collection_id corpus_id speaker_id target_child_id  transcript_id  \
# 3                  2        76       4228            4226          10155
# 5                  2        76       4228            4226          10155
# 7                  2        76       4228            4226          10155
# 8                  2        76       4228            4226          10155
# 10                 2        76       4228            4226          10155
# ...              ...       ...        ...             ...            ...
# 208557             2        76       5683            5679          11239
# 208594             2        76       5683            5679          11239
# 208603             2        76       5683            5679          11239
# 208604             2        76       5683            5679          11239
# 208626             2        76       5683            5679          11239
#
#                                       gloss_cleaned  \
# 3                                      oh yeah sure
# 5                                               mhm
# 7                                     alright okay
# 8                                   what looks good
# 10                                  what looks good
# ...                                             ...
# 208557                                         yeah
# 208594                           can you say pencil
# 208603                  thats when he usually signs
# 208604  so i'll be surprised if he actually does it
# 208626                                      oh yeah
#
#                                            phonemic_gloss  \
# 3                               [[ow], [j, æ], [ʃ, ʊ, ɹ]]
# 5                                                      []
# 7                            [[ɑ, ɫ, ɹ, aj, t], [cʰ, ej]]
# 8                       [[w, ɐ], [l, ʊ, k, s], [ɡ, ʊ, d]]
# 10                      [[w, ɐ], [l, ʊ, k, s], [ɡ, ʊ, d]]
# ...                                                   ...
# 208557                                           [[j, æ]]
# 208594   [[k, n̩], [j, ʉː], [s, ej], [pʰ, ɛ, n, s, ə, ɫ]]
# 208603  [[ð, æ, t, s], [w, ɪ, n], [iː], [j, ʉː, ʒ, ʊ, ...
# 208604  [[s, ow], [aj, ɫ], [bʲ, i], [s, ɚ, p, ɹ, aj, z...
# 208626                                     [[ow], [j, æ]]
#
#                                          phonemic_cleaned
# 3                               [[ow], [j, æ], [ʃ, ʊ, ɹ]]
# 5                                                      []
# 7                            [[ɑ, ɫ, ɹ, aj, t], [cʰ, ej]]
# 8                       [[w, ɐ], [l, ʊ, k, s], [ɡ, ʊ, d]]
# 10                      [[w, ɐ], [l, ʊ, k, s], [ɡ, ʊ, d]]
# ...                                                   ...
# 208557                                           [[j, æ]]
# 208594   [[k, n̩], [j, ʉː], [s, ej], [pʰ, ɛ, n, s, ə, ɫ]]
# 208603  [[ð, æ, t, s], [w, ɪ, n], [iː], [j, ʉː, ʒ, ʊ, ...
# 208604  [[s, ow], [aj, ɫ], [bʲ, i], [s, ɚ, p, ɹ, aj, z...
# 208626                                     [[ow], [j, æ]]
#
# [146158 rows x 30 columns]

# %% [markdown]
# ## Some  descriptive analysis

# %%
result_df = pd.read_csv(ipa_output_path)

# %%
import ast
how_many_words = []
how_many_phonemes = []
how_many_transcribed = []
for i in result_df['phonemic_gloss']:
    x = ast.literal_eval(i)
    how_many_words.append(len(x))
    ctr = 0
    phonemecount = 0
    for y in x: 
        phonemecount+=len(y)
        if y!='':
            ctr +=1
    how_many_transcribed.append(ctr)
    how_many_phonemes.append(phonemecount)

# %%
result_df['length_of_result'] = how_many_words
result_df['num_relevant_words'] = how_many_transcribed
result_df['num_phonemes'] = how_many_phonemes

# %%
print("Total number of words we had from CHILDES originally", result_df['num_tokens'].sum())
print("Total number of words we had after initial cleaning", result_df['length_of_result'].sum())
print("Total number of words we have transcriptions for", result_df['num_relevant_words'].sum())
print("Total number of phonemes we have ", result_df['num_phonemes'].sum())
# Out:
# Total number of words we had from CHILDES originally 685315
# Total number of words we had after initial cleaning 687991
# Total number of words we have transcriptions for 685413
# Total number of phonemes we have transcriptions for 1873661

# %%
subset_df = result_df[['gloss', 'target_child_age','target_child_sex','phonemic_gloss','num_relevant_words','num_phonemes']]
subset_df
# Out:
#                                               gloss  target_child_age  \
# 0                                      oh yeah sure          7.000144
# 1                                               mhm          7.000144
# 2                                  alright okay xxx          7.000144
# 3                                   what looks good          7.000144
# 4                                   what looks good          7.000144
# ...                                             ...               ...
# 146153                                         yeah         24.000493
# 146154                           can you say pencil         24.000493
# 146155                 that's when he usually signs         24.000493
# 146156  so I'll be surprised if he actually does it         24.000493
# 146157                                      oh yeah         24.000493
#
#        target_child_sex                                     phonemic_gloss  \
# 0                female              [['ow'], ['j', 'æ'], ['ʃ', 'ʊ', 'ɹ']]
# 1                female                                               ['']
# 2                female         [['ɑ', 'ɫ', 'ɹ', 'aj', 't'], ['cʰ', 'ej']]
# 3                female  [['w', 'ɐ'], ['l', 'ʊ', 'k', 's'], ['ɡ', 'ʊ', ...
# 4                female  [['w', 'ɐ'], ['l', 'ʊ', 'k', 's'], ['ɡ', 'ʊ', ...
# ...                 ...                                                ...
# 146153             male                                       [['j', 'æ']]
# 146154             male  [['k', 'n̩'], ['j', 'ʉː'], ['s', 'ej'], ['pʰ',...
# 146155             male  [['ð', 'æ', 't', 's'], ['w', 'ɪ', 'n'], ['iː']...
# 146156             male  [['s', 'ow'], ['aj', 'ɫ'], ['bʲ', 'i'], ['s', ...
# 146157             male                               [['ow'], ['j', 'æ']]
#
#         num_relevant_words  num_phonemes
# 0                        3             6
# 1                        0             0
# 2                        2             7
# 3                        3             9
# 4                        3             9
# ...                    ...           ...
# 146153                   1             2
# 146154                   4            12
# 146155                   5            19
# 146156                   9            27
# 146157                   2             3
#
# [146158 rows x 6 columns]

# %%
aggregated_df = subset_df.groupby(['target_child_age', 'target_child_sex']).agg({'num_relevant_words': 'sum','num_phonemes': 'sum'})

# %%
aggregated_df
# Out:
#                                    num_relevant_words  num_phonemes
# target_child_age target_child_sex
# 7.000144         female                         81324        221790
#                  male                           68863        188129
# 10.000205        female                         52330        143764
#                  male                           45243        125237
# 11.000226        female                         81838        225677
#                  male                           61962        169780
# 18.000370        female                         39664        108043
#                  male                           38359        104802
# 24.000493        female                        107671        292976
#                  male                          106394        288701

# %%
result_df.to_csv(ipa_output_path,index=False)

# %%
result_df
# Out:
#              id                                        gloss  \
# 0       2647047                                 oh yeah sure
# 1       2647067                                          mhm
# 2       2647084                             alright okay xxx
# 3       2647089                              what looks good
# 4       2647108                              what looks good
# ...         ...                                          ...
# 146153  2861987                                         yeah
# 146154  2862545                           can you say pencil
# 146155  2862655                 that's when he usually signs
# 146156  2862668  so I'll be surprised if he actually does it
# 146157  2863000                                      oh yeah
#
#                                        stem  actual_phonology  \
# 0                              oh yeah sure               NaN
# 1                                       mhm               NaN
# 2                              alright okay               NaN
# 3                            what look good               NaN
# 4                            what look good               NaN
# ...                                     ...               ...
# 146153                                 yeah               NaN
# 146154                   can you say pencil               NaN
# 146155              that when he usual sign               NaN
# 146156  so I be surprise if he actual do it               NaN
# 146157                              oh yeah               NaN
#
#         model_phonology                 type language  num_morphemes  \
# 0                   NaN          declarative      eng              3
# 1                   NaN          declarative      eng              1
# 2                   NaN          declarative      eng              2
# 3                   NaN             question      eng              4
# 4                   NaN             question      eng              4
# ...                 ...                  ...      ...            ...
# 146153              NaN  imperative_emphatic      eng              1
# 146154              NaN             question      eng              4
# 146155              NaN          declarative      eng              9
# 146156              NaN          declarative      eng             14
# 146157              NaN          declarative      eng              2
#
#         num_tokens  utterance_order  ... collection_id corpus_id speaker_id  \
# 0                3                4  ...             2        76       4228
# 1                1                6  ...             2        76       4228
# 2                3                8  ...             2        76       4228
# 3                3                9  ...             2        76       4228
# 4                3               11  ...             2        76       4228
# ...            ...              ...  ...           ...       ...        ...
# 146153           1              596  ...             2        76       5683
# 146154           4              633  ...             2        76       5683
# 146155           5              642  ...             2        76       5683
# 146156           9              643  ...             2        76       5683
# 146157           2              665  ...             2        76       5683
#
#        target_child_id transcript_id  \
# 0                 4226         10155
# 1                 4226         10155
# 2                 4226         10155
# 3                 4226         10155
# 4                 4226         10155
# ...                ...           ...
# 146153            5679         11239
# 146154            5679         11239
# 146155            5679         11239
# 146156            5679         11239
# 146157            5679         11239
#
#                                            phonemic_gloss  \
# 0                   [['ow'], ['j', 'æ'], ['ʃ', 'ʊ', 'ɹ']]
# 1                                                    ['']
# 2              [['ɑ', 'ɫ', 'ɹ', 'aj', 't'], ['cʰ', 'ej']]
# 3       [['w', 'ɐ'], ['l', 'ʊ', 'k', 's'], ['ɡ', 'ʊ', ...
# 4       [['w', 'ɐ'], ['l', 'ʊ', 'k', 's'], ['ɡ', 'ʊ', ...
# ...                                                   ...
# 146153                                       [['j', 'æ']]
# 146154  [['k', 'n̩'], ['j', 'ʉː'], ['s', 'ej'], ['pʰ',...
# 146155  [['ð', 'æ', 't', 's'], ['w', 'ɪ', 'n'], ['iː']...
# 146156  [['s', 'ow'], ['aj', 'ɫ'], ['bʲ', 'i'], ['s', ...
# 146157                               [['ow'], ['j', 'æ']]
#
#                                       gloss_cleaned length_of_result  \
# 0                                      oh yeah sure                3
# 1                                               mhm                1
# 2                                     alright okay                 2
# 3                                   what looks good                3
# 4                                   what looks good                3
# ...                                             ...              ...
# 146153                                         yeah                1
# 146154                           can you say pencil                4
# 146155                  thats when he usually signs                5
# 146156  so i'll be surprised if he actually does it                9
# 146157                                      oh yeah                2
#
#         num_relevant_words  num_phonemes
# 0                        3             6
# 1                        0             0
# 2                        2             7
# 3                        3             9
# 4                        3             9
# ...                    ...           ...
# 146153                   1             2
# 146154                   4            12
# 146155                   5            19
# 146156                   9            27
# 146157                   2             3
#
# [146158 rows x 32 columns]

# %%
result_df.to_csv(ipa_output_path,index=False)

# %% [markdown]
# # Now trying this pipeline on other corpora
#
# NewmanRatner : done above

# %% [markdown]
# ### BrentSiskind corpus

# %%
transcribed_text, preprocessed_df = runNotebookp1('Brent','english_us_mfa.dict')

# %%
path = runNotebookp2('Brent','english_us_mfa.dict')
# Out:
# Your job 4795968 ("job_script_item_name.sh") has been submitted

# %%
final_df = runNotebookp3('Brent','english_us_mfa.dict', path ,transcribed_text,preprocessed_df)
# Out:
# 148994

# %%
final_df
# Out:
#              id                           gloss                         stem  \
# 0       2138060                          Morgan                       Morgan
# 1       2138061             pull it up yourself          pull it up yourself
# 2       2138063                             see                          see
# 3       2138064                        hands up                      hand up
# 4       2138066                        hands up                      hand up
# ...         ...                             ...                          ...
# 168014  2330240                             xxx                          NaN
# 168015  2330241                        you want                     you want
# 168016  2330242              that what you want           that what you want
# 168017  2330243  you trying to snap your finger  you try to snap your finger
# 168018  2330244                  yep that's xxx                     yep that
#
#         actual_phonology  model_phonology                 type language  \
# 0                    NaN              NaN          declarative      eng
# 1                    NaN              NaN  imperative_emphatic      eng
# 2                    NaN              NaN  imperative_emphatic      eng
# 3                    NaN              NaN  imperative_emphatic      eng
# 4                    NaN              NaN  imperative_emphatic      eng
# ...                  ...              ...                  ...      ...
# 168014               NaN              NaN          declarative      eng
# 168015               NaN              NaN             question      eng
# 168016               NaN              NaN             question      eng
# 168017               NaN              NaN             question      eng
# 168018               NaN              NaN          declarative      eng
#
#         num_morphemes  num_tokens  utterance_order  ... media_unit  \
# 0                   1           1                1  ...          s
# 1                   4           4                1  ...          s
# 2                   1           1                2  ...          s
# 3                   3           2                2  ...          s
# 4                   3           2                3  ...          s
# ...               ...         ...              ...  ...        ...
# 168014    -2147483648           1             1087  ...          s
# 168015              2           2             1088  ...          s
# 168016              4           4             1089  ...          s
# 168017              7           6             1090  ...          s
# 168018              3           3             1091  ...          s
#
#        collection_name collection_id corpus_id speaker_id target_child_id  \
# 0               Eng-NA             2        68       3838            3832
# 1               Eng-NA             2        68       3837            3836
# 2               Eng-NA             2        68       3838            3832
# 3               Eng-NA             2        68       3837            3836
# 4               Eng-NA             2        68       3837            3836
# ...                ...           ...       ...        ...             ...
# 168014          Eng-NA             2        68       3892            3890
# 168015          Eng-NA             2        68       3892            3890
# 168016          Eng-NA             2        68       3892            3890
# 168017          Eng-NA             2        68       3892            3890
# 168018          Eng-NA             2        68       3892            3890
#
#         transcript_id                   gloss_cleaned  \
# 0                8268
# 1                8267             pull it up yourself
# 2                8268                             see
# 3                8267                        hands up
# 4                8267                        hands up
# ...               ...                             ...
# 168014           8477
# 168015           8477                        you want
# 168016           8477              that what you want
# 168017           8477  you trying to snap your finger
# 168018           8477                      yep thats
#
#                                            phonemic_gloss  \
# 0                                                      []
# 1        [[pʰ, ʊ, ɫ], [ɪ], [ɐ, p], [j, ʊ, ɹ, s, ɛ, ɫ, f]]
# 2                                               [[s, iː]]
# 3                                  [[h, æ, n, z], [ɐ, p]]
# 4                                  [[h, æ, n, z], [ɐ, p]]
# ...                                                   ...
# 168014                                                 []
# 168015                               [[j, ʉː], [w, ə, n]]
# 168016               [[ð, æ], [w, ɐ], [j, ʉː], [w, ə, n]]
# 168017  [[j, ʉː], [t, ɹ, aj, ɪ, n], [tʰ, ʊ], [s, ɲ, æ,...
# 168018                          [[j, ə, p], [ð, æ, t, s]]
#
#                                          phonemic_cleaned
# 0                                                      []
# 1        [[pʰ, ʊ, ɫ], [ɪ], [ɐ, p], [j, ʊ, ɹ, s, ɛ, ɫ, f]]
# 2                                               [[s, iː]]
# 3                                  [[h, æ, n, z], [ɐ, p]]
# 4                                  [[h, æ, n, z], [ɐ, p]]
# ...                                                   ...
# 168014                                                 []
# 168015                               [[j, ʉː], [w, ə, n]]
# 168016               [[ð, æ], [w, ɐ], [j, ʉː], [w, ə, n]]
# 168017  [[j, ʉː], [t, ɹ, aj, ɪ, n], [tʰ, ʊ], [s, ɲ, æ,...
# 168018                          [[j, ə, p], [ð, æ, t, s]]
#
# [148994 rows x 30 columns]

# %% [markdown]
# ### Rollins corpus

# %%
transcribed_text, preprocessed_df = runNotebookp1('Rollins','english_us_mfa.dict')

# %%
path = runNotebookp2('Rollins','english_us_mfa.dict')
# Out:
# Your job 4796000 ("job_script_item_name.sh") has been submitted

# %%
final_df = runNotebookp3('Rollins','english_us_mfa.dict', path ,transcribed_text,preprocessed_df)
# Out:
# 17246

# %%
final_df
# Out:
#            id                         gloss                        stem  \
# 0      906608                     hello Chi                   hello Chi
# 1      906617             how are you today            how be you today
# 4      906635                    I love you                  I love you
# 6      906648                    I love you                  I love you
# 7      906654                            uh                         NaN
# ...       ...                           ...                         ...
# 27744  943620             what did you find            what do you find
# 27748  943662  can Chi make the birdie sing  can Chi make the bird sing
# 27750  943684                     very good                   very good
# 27753  943712        oh that rattle is nice      oh that rattle be nice
# 27755  943733                 make it sound               make it sound
#
#        actual_phonology  model_phonology         type language  num_morphemes  \
# 0                   NaN              NaN  declarative      eng              2
# 1                   NaN              NaN  declarative      eng              5
# 4                   NaN              NaN  declarative      eng              3
# 6                   NaN              NaN  declarative      eng              3
# 7                   NaN              NaN  declarative      eng    -2147483648
# ...                 ...              ...          ...      ...            ...
# 27744               NaN              NaN     question      eng              5
# 27748               NaN              NaN     question      eng              7
# 27750               NaN              NaN  declarative      eng              2
# 27753               NaN              NaN  declarative      eng              6
# 27755               NaN              NaN  declarative      eng              3
#
#        num_tokens  utterance_order  ... media_unit collection_name  \
# 0               2                1  ...          s          Eng-NA
# 1               4                2  ...          s          Eng-NA
# 4               3                5  ...          s          Eng-NA
# 6               3                7  ...          s          Eng-NA
# 7               1                8  ...          s          Eng-NA
# ...           ...              ...  ...        ...             ...
# 27744           4              629  ...          s          Eng-NA
# 27748           6              633  ...          s          Eng-NA
# 27750           2              635  ...          s          Eng-NA
# 27753           5              638  ...          s          Eng-NA
# 27755           3              640  ...          s          Eng-NA
#
#       collection_id corpus_id speaker_id target_child_id  transcript_id  \
# 0                 2        47       2532            2530           4523
# 1                 2        47       2532            2530           4523
# 4                 2        47       2532            2530           4523
# 6                 2        47       2532            2530           4523
# 7                 2        47       2532            2530           4523
# ...             ...       ...        ...             ...            ...
# 27744             2        47       2532            2530           4650
# 27748             2        47       2532            2530           4650
# 27750             2        47       2532            2530           4650
# 27753             2        47       2532            2530           4650
# 27755             2        47       2532            2530           4650
#
#                       gloss_cleaned  \
# 0                         hello chi
# 1                 how are you today
# 4                        i love you
# 6                        i love you
# 7                                uh
# ...                             ...
# 27744             what did you find
# 27748  can chi make the birdie sing
# 27750                     very good
# 27753        oh that rattle is nice
# 27755                 make it sound
#
#                                           phonemic_gloss  \
# 0                               [[h, ɛ, l, ow], [ʃ, aj]]
# 1                [[h, aw], [ɚ], [j, ʉː], [tʰ, ʊ, d, ej]]
# 4                             [[aj], [l, ɐ, v], [j, ʉː]]
# 6                             [[aj], [l, ɐ, v], [j, ʉː]]
# 7                                                  [[ə]]
# ...                                                  ...
# 27744          [[w, ɐ], [dʲ, ɪ, d], [j, ʉː], [f, aj, n]]
# 27748  [[k, n̩], [ʃ, aj], [m, ej, k], [d̪, iː], [b, ɝ...
# 27750                          [[v, ɛ, ɹ, i], [ɡ, ʊ, d]]
# 27753   [[ow], [ð, æ], [ɹ, æ, t, ə, ɫ], [z], [n, aj, s]]
# 27755                      [[m, ej, k], [ɪ], [s, aw, n]]
#
#                                         phonemic_cleaned
# 0                               [[h, ɛ, l, ow], [ʃ, aj]]
# 1                [[h, aw], [ɚ], [j, ʉː], [tʰ, ʊ, d, ej]]
# 4                             [[aj], [l, ɐ, v], [j, ʉː]]
# 6                             [[aj], [l, ɐ, v], [j, ʉː]]
# 7                                                  [[ə]]
# ...                                                  ...
# 27744          [[w, ɐ], [dʲ, ɪ, d], [j, ʉː], [f, aj, n]]
# 27748  [[k, n̩], [ʃ, aj], [m, ej, k], [d̪, iː], [b, ɝ...
# 27750                          [[v, ɛ, ɹ, i], [ɡ, ʊ, d]]
# 27753   [[ow], [ð, æ], [ɹ, æ, t, ə, ɫ], [z], [n, aj, s]]
# 27755                      [[m, ej, k], [ɪ], [s, aw, n]]
#
# [17246 rows x 30 columns]

# %% [markdown]
# ### Providence corpus

# %%
transcribed_text, preprocessed_df = runNotebookp1('Providence','english_us_mfa.dict')

# %%
path = runNotebookp2('Providence','english_us_mfa.dict')
# Out:
# Your job 4980722 ("job_script_item_name.sh") has been submitted

# %%
final_df = runNotebookp3('Providence','english_us_mfa.dict', path ,transcribed_text,preprocessed_df)

# %% [markdown]
# ### Vankleeck corpus

# %%
transcribed_text, preprocessed_df = runNotebookp1('Vankleeck','english_us_mfa.dict')
# Out:
# Total number of CDS utterances in corpus (includes null values): 8756
# Total number of non-null CDS utterances in corpus: 8756
# Total number of word tokens originally in corpus: 38091
# Total number of word tokens found during preprocessing: 38393
# Total number of word tokens left after preprocessing: 38067
# Total number of UNIQUE word types left after preprocessing: 1743
# Total number of word tokens we threw out: 326
# Total number of word tokens which could not be recognized in dictionary-based g2p: 1548
# Total number of UNIQUE word types which could not be recognized in dictionary-based g2p: 129
# Percentage of total word tokens it could not transcribe:  4.031984997265126 %

# %%
path = runNotebookp2('Vankleeck','english_us_mfa.dict')
# Out:
# Your job 4984984 ("job_script_item_name.sh") has been submitted

# %%
final_df = runNotebookp3('Vankleeck','english_us_mfa.dict', path ,transcribed_text,preprocessed_df)

# %%
final_df
# Out:
#            id                                              gloss  \
# 0      809791                           wanna play with the farm
# 1      809798                                               okay
# 2      809804                                     can I play too
# 3      809813                                         is it okay
# 4      809820                       Amy what happened to the cow
# ...       ...                                                ...
# 15424  837110                                           what now
# 15426  837140  oh we can't make some because we're going to s...
# 15428  837174                            what did you sing today
# 15429  837188                                did you go to music
# 15432  837233                           what do you wanna do now
#
#                                                     stem  actual_phonology  \
# 0                                want play with the farm               NaN
# 1                                                   okay               NaN
# 2                                         can I play too               NaN
# 3                                             be it okay               NaN
# 4                             Amy what happen to the cow               NaN
# ...                                                  ...               ...
# 15424                                           what now               NaN
# 15426  oh we can make some because we go to school I see               NaN
# 15428                             what do you sing today               NaN
# 15429                                 do you go to music               NaN
# 15432                            what do you want do now               NaN
#
#        model_phonology         type language  num_morphemes  num_tokens  \
# 0                  NaN     question      eng              6           5
# 1                  NaN  declarative      eng              1           1
# 2                  NaN     question      eng              4           4
# 3                  NaN     question      eng              4           3
# 4                  NaN     question      eng              7           6
# ...                ...          ...      ...            ...         ...
# 15424              NaN     question      eng              2           2
# 15426              NaN  declarative      eng             15          12
# 15428              NaN     question      eng              6           5
# 15429              NaN     question      eng              6           5
# 15432              NaN     question      eng              7           6
#
#        utterance_order  ... media_unit collection_name collection_id  \
# 0                    1  ...        NaN          Eng-NA             2
# 1                    2  ...        NaN          Eng-NA             2
# 2                    3  ...        NaN          Eng-NA             2
# 3                    4  ...        NaN          Eng-NA             2
# 4                    5  ...        NaN          Eng-NA             2
# ...                ...  ...        ...             ...           ...
# 15424              571  ...        NaN          Eng-NA             2
# 15426              573  ...        NaN          Eng-NA             2
# 15428              575  ...        NaN          Eng-NA             2
# 15429              576  ...        NaN          Eng-NA             2
# 15432              579  ...        NaN          Eng-NA             2
#
#       corpus_id speaker_id target_child_id  transcript_id  \
# 0            44       2477            2476           4258
# 1            44       2477            2476           4258
# 2            44       2477            2476           4258
# 3            44       2477            2476           4258
# 4            44       2477            2476           4258
# ...         ...        ...             ...            ...
# 15424        44       2498            2495           4277
# 15426        44       2498            2495           4277
# 15428        44       2498            2495           4277
# 15429        44       2498            2495           4277
# 15432        44       2498            2495           4277
#
#                                            gloss_cleaned  \
# 0                               wanna play with the farm
# 1                                                   okay
# 2                                         can i play too
# 3                                             is it okay
# 4                               what happened to the cow
# ...                                                  ...
# 15424                                           what now
# 15426  oh we can't make some because we're going to s...
# 15428                            what did you sing today
# 15429                                did you go to music
# 15432                           what do you wanna do now
#
#                                           phonemic_gloss  \
# 0      [[w, ə, n, ə], [p, l, ej], [w, ɪ, θ], [ð], [f,...
# 1                                             [[cʰ, ej]]
# 2                   [[k, n̩], [aj], [p, l, ej], [tʰ, ʉ]]
# 3                                   [[z], [ɪ], [cʰ, ej]]
# 4      [[w, ɐ], [h, æ, p, ə, n, d], [tʰ, ʊ], [ð], [kʰ...
# ...                                                  ...
# 15424                                  [[w, ɐ], [n, aw]]
# 15426  [[ow], [w, iː], [k, ə, n, t], [m, ej, k], [s, ...
# 15428  [[w, ɐ], [dʲ, ɪ, d], [j, ʉː], [s, ɪ, n], [tʰ, ...
# 15429  [[dʲ, ɪ, d], [j, ʉː], [ɡ, ow], [tʰ, ʊ], [mʲ, ʉ...
# 15432  [[w, ɐ], [d, ʉː], [j, ʉː], [w, ə, n, ə], [d, ʉ...
#
#                                         phonemic_cleaned
# 0      [[w, ə, n, ə], [p, l, ej], [w, ɪ, θ], [ð], [f,...
# 1                                             [[cʰ, ej]]
# 2                   [[k, n̩], [aj], [p, l, ej], [tʰ, ʉ]]
# 3                                   [[z], [ɪ], [cʰ, ej]]
# 4      [[w, ɐ], [h, æ, p, ə, n, d], [tʰ, ʊ], [ð], [kʰ...
# ...                                                  ...
# 15424                                  [[w, ɐ], [n, aw]]
# 15426  [[ow], [w, iː], [k, ə, n, t], [m, ej, k], [s, ...
# 15428  [[w, ɐ], [dʲ, ɪ, d], [j, ʉː], [s, ɪ, n], [tʰ, ...
# 15429  [[dʲ, ɪ, d], [j, ʉː], [ɡ, ow], [tʰ, ʊ], [mʲ, ʉ...
# 15432  [[w, ɐ], [d, ʉː], [j, ʉː], [w, ə, n, ə], [d, ʉ...
#
# [8756 rows x 30 columns]

# %% [markdown]
# ## Descriptive analyses of different corpora - SUMMARY STATS

# %% [markdown]
# ## NewmanRatner

# %%
subset, aggr = util.tokenDescriptions(directory_of_output,'NewmanRatner')
# Out:
# Total number of words we had from CHILDES originally 685315
# Total number of words we had after initial cleaning 687991
# Total number of words we have transcriptions for 684703
# Total number of phonemes we have  1871118
# Total number of  unique child IDs detected: 503
# Total number of  unique speaker roles detected: 1

# %%
uid_list = (list(set(subset['target_child_name'])))

# %%
processed_uids = []
only7s = []
only10s = []
only11s = []
only18s = []
only24s = []

for uid in uid_list:
    if isinstance(uid, str):
        processed_uids.append(str(uid)[:4])
        if uid[-1] == '7':
            only7s.append(uid[:6])
        elif uid[-2:] == "10":
            only10s.append(uid[:6])
        elif uid[-2:] == "11":
            only11s.append(uid[:6])
        elif uid[-2:] == "18":
            only18s.append(uid[:6])
        elif uid[-2:] == "24":
            only24s.append(uid[:6])
            
print ('total number of unique child IDs now,', len(set(processed_uids)))
print ('total number of unique child IDs sampled at 7  mos,', len(set(only7s)))
print ('total number of unique child IDs sampled at 10 mos,', len(set(only10s)))
print ('total number of unique child IDs sampled at 11 mos,', len(set(only11s)))
print ('total number of unique child IDs sampled at 18 mos,', len(set(only18s)))
print ('total number of unique child IDs sampled at 24 mos,', len(set(only24s)))
# Out:
# total number of unique child IDs now, 124
# total number of unique child IDs sampled at 7  mos, 125
# total number of unique child IDs sampled at 10 mos, 84
# total number of unique child IDs sampled at 11 mos, 113
# total number of unique child IDs sampled at 18 mos, 55
# total number of unique child IDs sampled at 24 mos, 123

# %%
len(full_set)
# Out:
# 124

# %%
subset['child_id_initials'] =  subset['target_child_name'].str[:6]
subset['child_id'] =  subset['target_child_name'].str[:4]

# %%
subset
# Out:
#                                               gloss target_child_name  \
# 0                                      oh yeah sure           4269LP7
# 1                                               mhm           4269LP7
# 2                                  alright okay xxx           4269LP7
# 3                                   what looks good           4269LP7
# 4                                   what looks good           4269LP7
# ...                                             ...               ...
# 146153                                         yeah          7300AP24
# 146154                           can you say pencil          7300AP24
# 146155                 that's when he usually signs          7300AP24
# 146156  so I'll be surprised if he actually does it          7300AP24
# 146157                                      oh yeah          7300AP24
#
#         transcript_id  target_child_age target_child_sex  target_child_id  \
# 0               10155          7.000144           female             4226
# 1               10155          7.000144           female             4226
# 2               10155          7.000144           female             4226
# 3               10155          7.000144           female             4226
# 4               10155          7.000144           female             4226
# ...               ...               ...              ...              ...
# 146153          11239         24.000493             male             5679
# 146154          11239         24.000493             male             5679
# 146155          11239         24.000493             male             5679
# 146156          11239         24.000493             male             5679
# 146157          11239         24.000493             male             5679
#
#                                            phonemic_gloss  num_relevant_words  \
# 0                   [['ow'], ['j', 'æ'], ['ʃ', 'ʊ', 'ɹ']]                   3
# 1                                                    ['']                   0
# 2              [['ɑ', 'ɫ', 'ɹ', 'aj', 't'], ['cʰ', 'ej']]                   2
# 3       [['w', 'ɐ'], ['l', 'ʊ', 'k', 's'], ['ɡ', 'ʊ', ...                   3
# 4       [['w', 'ɐ'], ['l', 'ʊ', 'k', 's'], ['ɡ', 'ʊ', ...                   3
# ...                                                   ...                 ...
# 146153                                       [['j', 'æ']]                   1
# 146154  [['k', 'n̩'], ['j', 'ʉː'], ['s', 'ej'], ['pʰ',...                   4
# 146155  [['ð', 'æ', 't', 's'], ['w', 'ɪ', 'n'], ['iː']...                   5
# 146156  [['s', 'ow'], ['aj', 'ɫ'], ['bʲ', 'i'], ['s', ...                   9
# 146157                               [['ow'], ['j', 'æ']]                   2
#
#         num_phonemes child_id_initials child_id
# 0                  6            4269LP     4269
# 1                  0            4269LP     4269
# 2                  7            4269LP     4269
# 3                  9            4269LP     4269
# 4                  9            4269LP     4269
# ...              ...               ...      ...
# 146153             2            7300AP     7300
# 146154            12            7300AP     7300
# 146155            19            7300AP     7300
# 146156            27            7300AP     7300
# 146157             3            7300AP     7300
#
# [146158 rows x 11 columns]

# %%
print("Total no of unique child IDs found:", subset['child_id'].nunique())
# Out:
# Total no of unique child IDs found: 124

# %%
print("Total no of unique child ID-initial strings:", subset['child_id_initials'].nunique())
# Out:
# Total no of unique child ID-initial strings: 130

# %%
subset.to_csv(os.path.join(directory_of_output,'NewmanRatner_id_fixed.csv'))

# %%
newman_binned = util.binInto6(subset)

# %%
util.ageSexSummary(subset)
# Out:
#    target_child_age target_child_sex  total_words  total_phonemes  \
# 0          7.000144           female        81273          221594
# 1          7.000144             male        68840          188074
# 2         10.000205           female        52274          143573
# 3         10.000205             male        45214          125146
# 4         11.000226           female        81684          225043
# 5         11.000226             male        61906          169620
# 6         18.000370           female        39613          107854
# 7         18.000370             male        38304          104597
# 8         24.000493           female       107516          292371
# 9         24.000493             male       106314          288482
#
#    no_unique_child
# 0               62
# 1               61
# 2               42
# 3               41
# 4               60
# 5               51
# 6               27
# 7               26
# 8               61
# 9               59

# %%
util.ageSexSummary(newman_binned)

# %%
corpusname = "NewmanRatner"
aggregation  = util.ageSexSummary(newman_binned)
aggregation.to_csv("aggregation_"+corpusname+".csv",index=False)

# %% [markdown]
# ## BrentSiskind

# %%
subset, aggr = util.tokenDescriptions(directory_of_output,'Brent')
# Out:
# Total number of words we had from CHILDES originally 504910
# Total number of words we had after initial cleaning 497307
# Total number of words we have transcriptions for 495578
# Total number of phonemes we have  1373980
# Total number of  unique child IDs detected: 19
# Total number of  unique speaker roles detected: 2

# %%
howManyUnique(subset['target_child_id'])
# Out:
# 19

# %% [markdown]
# #### Fixing Brent corpus scraping by working on ages and number of subjects

# %%
brent_transcripts = pd.read_csv('dictAlignment/brent_transcripts.csv')

# %%
child_ids = []
agestrings = []
actualages = []
for filename in brent_transcripts['filename']:
    components = filename.split('/')
    child_ids.append(components[2])
    agestrings.append((components[3])[:-4])

actualages=[]
for agestring in agestrings:
    if agestring[:2] =='m1':
        actualages.append(0)
        continue
    if agestring[-1] in ['a','b']:
        agestring = agestring[:-1]
    
    yrs = int(agestring[:2])
    mos =  int(agestring[2:4])
    days =  int(agestring[4:])
    totalmos = 12*yrs + mos + days/30.5
    actualages.append(totalmos)

# %%
brent_transcripts['target_child_age_old'] = brent_transcripts['target_child_age']
brent_transcripts['target_child_age'] = actualages
brent_transcripts['child_id'] = child_ids

# %%
brent_transcripts_relevant = brent_transcripts[['transcript_id','child_id', 'target_child_age','target_child_age_old']]

# %% [markdown]
# Now merging this data with the original utterance-level data and then producing summary stats. Note that m1 child should be deleted as the sessions were not transcribed.

# %%
merged_brent_results = pd.merge(subset,brent_transcripts_relevant,how='left',on='transcript_id').drop(['target_child_age_x'],axis=1)
merged_brent_results = merged_brent_results.rename(columns={"target_child_age_y": "target_child_age"})

# %%
binned_brent = util.binInto6(merged_brent_results)

# %%
merged_brent_results['child_id'].value_counts()
# Out:
# child_id
# s2    15983
# v1    13255
# s1    13194
# i1    12827
# d1    11070
# c1    10366
# f2    10322
# w1    10171
# f1     9546
# w3     8876
# v2     8398
# t1     7709
# j1     6944
# s3     3745
# m2     3355
# q1     3233
# Name: count, dtype: int64

# %% [markdown]
# Note - the utterance level scraping did not have m1 results to begin with
# age bracket 9-10 means inclusive of 9, not of 10

# %%
util.ageSexSummary(merged_brent_results)
# Out:
#      target_child_age target_child_sex  total_words  total_phonemes  \
# 0            8.918033             male         5283           13951
# 1            9.032787             male         2910            7895
# 2            9.065574             male         3342            9260
# 3            9.131148           female         3953           11419
# 4            9.262295             male         1157            3111
# ..                ...              ...          ...             ...
# 113         15.131148             male         4430           11973
# 114         15.163934             male          948            2467
# 115         15.196721             male         4212           11722
# 116         15.262295             male         3530            9722
# 117         15.393443             male         1922            5175
#
#      no_unique_child
# 0                  2
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ..               ...
# 113                2
# 114                1
# 115                1
# 116                1
# 117                1
#
# [118 rows x 5 columns]

# %%
util.ageSexSummary(binned_brent)

# %%
corpusname = "Brent"
aggregation  = util.ageSexSummary(binned_brent)
aggregation.to_csv("aggregation_"+corpusname+".csv",index=False)

# %%
merged_brent_results
# Out:
#                                  gloss target_child_name  transcript_id  \
# 0                               Morgan               NaN           8268
# 1                  pull it up yourself            Morgan           8267
# 2                                  see               NaN           8268
# 3                             hands up            Morgan           8267
# 4                             hands up            Morgan           8267
# ...                                ...               ...            ...
# 148989                             xxx       Vas_Coleman           8477
# 148990                        you want       Vas_Coleman           8477
# 148991              that what you want       Vas_Coleman           8477
# 148992  you trying to snap your finger       Vas_Coleman           8477
# 148993                  yep that's xxx       Vas_Coleman           8477
#
#        target_child_sex  target_child_id  \
# 0                   NaN             3832
# 1                female             3836
# 2                   NaN             3832
# 3                female             3836
# 4                female             3836
# ...                 ...              ...
# 148989             male             3890
# 148990             male             3890
# 148991             male             3890
# 148992             male             3890
# 148993             male             3890
#
#                                            phonemic_gloss  num_relevant_words  \
# 0                                                      []                   0
# 1       [['pʰ', 'ʊ', 'ɫ'], ['ɪ'], ['ɐ', 'p'], ['j', 'ʊ...                   4
# 2                                           [['s', 'iː']]                   1
# 3                      [['h', 'æ', 'n', 'z'], ['ɐ', 'p']]                   2
# 4                      [['h', 'æ', 'n', 'z'], ['ɐ', 'p']]                   2
# ...                                                   ...                 ...
# 148989                                                 []                   0
# 148990                     [['j', 'ʉː'], ['w', 'ə', 'n']]                   2
# 148991  [['ð', 'æ'], ['w', 'ɐ'], ['j', 'ʉː'], ['w', 'ə...                   4
# 148992  [['j', 'ʉː'], ['t', 'ɹ', 'aj', 'ɪ', 'n'], ['tʰ...                   6
# 148993            [['j', 'ə', 'p'], ['ð', 'æ', 't', 's']]                   2
#
#         num_phonemes child_id  target_child_age  target_child_age_old
# 0                  0       c1          9.983607                   NaN
# 1                 13       c1          9.557377              9.558718
# 2                  2       c1          9.983607                   NaN
# 3                  6       c1          9.557377              9.558718
# 4                  6       c1          9.557377              9.558718
# ...              ...      ...               ...                   ...
# 148989             0       w3         14.950820             14.953079
# 148990             5       w3         14.950820             14.953079
# 148991             9       w3         14.950820             14.953079
# 148992            21       w3         14.950820             14.953079
# 148993             7       w3         14.950820             14.953079
#
# [148994 rows x 11 columns]

# %%
merged_brent_results.to_csv((os.path.join(directory_of_output,'Brent_id_fixed.csv')))

# %% [markdown]
# ## Rollins

# %%
subset, aggr = util.tokenDescriptions(directory_of_output,'Rollins')

# %% [markdown]
# #### Fixing Rollins corpus scraping by working on ages and number of subjects

# %%
def howManyUnique(l):
    return len(set(l))

# %%
rollins_transcripts = pd.read_csv('dictAlignment/rollins_transcripts.csv')
child_ids = []
actualages = []
for filename in rollins_transcripts['filename']:
    components = filename.split('/')
    initials_age = components[2] [:-4] 
    child_ids.append(initials_age[:2])
    actualages.append(int(initials_age[2:4]))

# %%
rollins_transcripts['target_child_age_old'] = rollins_transcripts['target_child_age']
rollins_transcripts['target_child_age'] = actualages
rollins_transcripts['child_id'] = child_ids

# %%
rollins_transcripts_relevant = rollins_transcripts[['transcript_id','child_id', 'target_child_age','target_child_age_old']]
merged_rollins_results = pd.merge(subset,rollins_transcripts_relevant,how='left',on='transcript_id').drop(['target_child_age_x'],axis=1)
merged_rollins_results = merged_rollins_results.rename(columns={"target_child_age_y": "target_child_age"})

# %%
merged_rollins_results
# Out:
#                               gloss target_child_name  transcript_id  \
# 0                         hello Chi               NaN           4523
# 1                 how are you today               NaN           4523
# 2                        I love you               NaN           4523
# 3                        I love you               NaN           4523
# 4                                uh               NaN           4523
# ...                             ...               ...            ...
# 17241             what did you find               NaN           4650
# 17242  can Chi make the birdie sing               NaN           4650
# 17243                     very good               NaN           4650
# 17244        oh that rattle is nice               NaN           4650
# 17245                 make it sound               NaN           4650
#
#       target_child_sex  target_child_id  \
# 0                  NaN             2530
# 1                  NaN             2530
# 2                  NaN             2530
# 3                  NaN             2530
# 4                  NaN             2530
# ...                ...              ...
# 17241              NaN             2530
# 17242              NaN             2530
# 17243              NaN             2530
# 17244              NaN             2530
# 17245              NaN             2530
#
#                                           phonemic_gloss  num_relevant_words  \
# 0                   [['h', 'ɛ', 'l', 'ow'], ['ʃ', 'aj']]                   2
# 1      [['h', 'aw'], ['ɚ'], ['j', 'ʉː'], ['tʰ', 'ʊ', ...                   4
# 2                 [['aj'], ['l', 'ɐ', 'v'], ['j', 'ʉː']]                   3
# 3                 [['aj'], ['l', 'ɐ', 'v'], ['j', 'ʉː']]                   3
# 4                                                [['ə']]                   1
# ...                                                  ...                 ...
# 17241  [['w', 'ɐ'], ['dʲ', 'ɪ', 'd'], ['j', 'ʉː'], ['...                   4
# 17242  [['k', 'n̩'], ['ʃ', 'aj'], ['m', 'ej', 'k'], [...                   6
# 17243            [['v', 'ɛ', 'ɹ', 'i'], ['ɡ', 'ʊ', 'd']]                   2
# 17244  [['ow'], ['ð', 'æ'], ['ɹ', 'æ', 't', 'ə', 'ɫ']...                   5
# 17245        [['m', 'ej', 'k'], ['ɪ'], ['s', 'aw', 'n']]                   3
#
#        num_phonemes child_id  target_child_age  target_child_age_old
# 0                 6       cb                 6              6.000123
# 1                 9       cb                 6              6.000123
# 2                 6       cb                 6              6.000123
# 3                 6       cb                 6              6.000123
# 4                 1       cb                 6              6.000123
# ...             ...      ...               ...                   ...
# 17241            10       nb                12             12.000246
# 17242            16       nb                12             12.000246
# 17243             7       nb                12             12.000246
# 17244            12       nb                12             12.000246
# 17245             7       nb                12             12.000246
#
# [17246 rows x 11 columns]

# %%
binned_rollins = util.binInto6(merged_rollins_results)

# %%
util.ageSexSummary(binned_rollins,False)

# %%
corpusname = "Rollins"
aggregation  = util.ageSexSummary(binned_rollins,False)
aggregation.to_csv("aggregation_"+corpusname+".csv",index=False)

# %%
merged_rollins_results.to_csv(os.path.join(directory_of_output,'Rollins_id_fixed.csv'))

# %% [markdown]
# ## Providence

# %%
subset, aggr = util.tokenDescriptions(directory_of_output,'Providence')

# %%
subset['child_id']= subset['target_child_id']

# %%
binned_subset = util.binInto6(subset)

# %%
util.ageSexSummary(binned_subset)

# %%
corpusname = "Providence"
aggregation  = util.ageSexSummary(binned_subset)
aggregation.to_csv("aggregation_"+corpusname+".csv",index=False)

# %% [markdown]
# ## Vankleeck

# %%
subset, aggr = util.tokenDescriptions(directory_of_output,'Vankleeck')
# Out:
# Total number of words we had from CHILDES originally 38091
# Total number of words we had after initial cleaning 38067
# Total number of words we have transcriptions for 37863
# Total number of phonemes we have  97470
# Total number of  unique child IDs detected: 20
# Total number of  unique speaker roles detected: 1

# %%
subset['child_id']= subset['target_child_id']

# %%
binned_subset = util.binInto6(subset)

# %%
util.ageSexSummary(binned_subset)

# %%
corpusname = "Vankleeck"
aggregation  = util.ageSexSummary(binned_subset)
aggregation.to_csv("aggregation_"+corpusname+".csv",index=False)

# %% [markdown]
# ## Total aggregation

# %%
corpora_names = ['Providence', 'NewmanRatner', 'Vankleeck', 'Rollins', 'Brent']
summaries = []
for corpus in corpora_names:
    df = pd.read_csv("aggregation_"+corpus+".csv")
    df['corpus'] = corpus
    summaries.append(df)
full_merge = pd.concat([d for d in summaries]).reset_index().drop('index',axis=1)

# %%
full_merge
# Out:
#    age_bin target_child_sex  total_words  total_phonemes  no_unique_child  \
# 0      3-9           female            0               0                0
# 1      3-9             male            0               0                0
# 2     9-15           female        46073          133548                3
# 3     9-15             male        27565           78968                1
# 4    15-21           female       179814          515536                3
# ..     ...              ...          ...             ...              ...
# 67   33-39             male            0               0                0
# 68   39-45           female            0               0                0
# 69   39-45             male            0               0                0
# 70   45-51           female            0               0                0
# 71   45-51             male            0               0                0
#
#         corpus
# 0   Providence
# 1   Providence
# 2   Providence
# 3   Providence
# 4   Providence
# ..         ...
# 67       Brent
# 68       Brent
# 69       Brent
# 70       Brent
# 71       Brent
#
# [72 rows x 6 columns]

# %%
tp = full_merge
tp['age_bin'] = pd.Categorical(full_merge['age_bin'], categories=[str(i)+"-"+str(i+6) for i in range(3,47,6)], ordered=True)

# %%
all_grouped = tp.groupby(['age_bin', 'target_child_sex']).agg(total_words = ('total_words', 'sum'),total_phonemes = ('total_phonemes','sum'), no_unique_child = ('no_unique_child', 'sum')).reset_index()
# Out:
# /tmp/ipykernel_19120/4118686673.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tp.groupby(['age_bin', 'target_child_sex']).agg(total_words = ('total_words', 'sum'),total_phonemes = ('total_phonemes','sum'), no_unique_child = ('no_unique_child', 'sum')).reset_index()
#    age_bin target_child_sex  total_words  total_phonemes  no_unique_child
# 0      3-9           female        81273          221594               62
# 1      3-9             male        75424          205491               64
# 2     9-15           female       331731          930054               72
# 3     9-15             male       355061          980234               72
# 4    15-21           female       221678          629824               31
# 5    15-21             male       145369          404059               36
# 6    21-27           female       310965          873592               64
# 7    21-27             male       214465          588780               62
# 8    27-33           female       206927          592396                3
# 9    27-33             male       131512          365550                3
# 10   33-39           female       130123          372760                4
# 11   33-39             male        87193          240962                3
# 12   39-45           female        52693          148935                6
# 13   39-45             male        31672           85112                5
# 14   45-51           female        37140          104718                6
# 15   45-51             male        17848           45675               10

# %%
all_grouped = tp.groupby(['age_bin', 'target_child_sex']).agg(total_words = ('total_words', 'sum'),total_phonemes = ('total_phonemes','sum'), no_unique_child = ('no_unique_child', 'sum')).reset_index()

# %%
all_grouped.to_csv("grouped_aggregation.csv",index=False)

# %%
full_merge.to_csv("grouped_aggregation_corpuslevel.csv",index=False)
